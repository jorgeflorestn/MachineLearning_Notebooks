# %% [markdown]
# # Regresión lineal
# Para este caso, se implementa al intentar describir una suceción de puntos a una ecuación de una recta

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 150
X = 2 * np.random.rand(m, 1)
y = 3 + 4*X + 1.5*np.random.randn(m, 1)

# %%
plt.plot(X, y, "b.")
plt.xlabel('X', fontsize = 16)
plt.ylabel('y', fontsize = 16, rotation = 0)
plt.axis([0, 2, 0, 15])
plt.grid(True)
plt.show()

# %%
sx = 0
sy = 0
sx2 = 0
mx = np.mean(X)
my = np.mean(y)
for i in X:
    sx = sx + (i - mx)
for j in X:
    sx2 = sx2 + (j - mx)**2
for k in y:
    sy = sy + (k - my)

betha = sx * sy / sx2

# %%
mx = np.mean(X)
my = np.mean(y)
betha = np.sum((X - mx * (y - my))/np.sum((X - mx)**2))

# %%
alpha = my - betha * mx

# %%
# Out:
# array([[3.09261047, 0.        ],
#        [3.09261047, 2.31945785],
#        [3.09261047, 4.6389157 ],
#        [3.09261047, 6.18522094]])

# %%
plt.plot(X, y, "b.")
plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")
plt.xlabel('X', fontsize = 16)
plt.ylabel('y', fontsize = 16, rotation = 0)
plt.axis([0, 2, 0, 15])
plt.grid(True)
plt.show()
